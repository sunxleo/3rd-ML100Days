# %% [markdown]
# # 請結合前面的知識與程式碼，比較不同的 optimizer 與 learning rate 組合對訓練的結果與影響
# ### 常見的 optimizer 包含
# * SGD
# * RMSprop
# * AdaGrad
# * Adam

# %%
import os
import keras

# Disable GPU
#os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

def build_mlp(input, output):
    """
    Build your own model
    """
    model = Sequential()
    model.add(Dense(256,input_dim = input, activation='relu'))
    model.add(Dense(128,activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(output, activation='softmax'))
    return model

# %%
## 超參數設定
"""
Set your required experiment parameters
"""
from keras.optimizers import SGD,RMSprop,Adagrad,Adam

LR =1e-3
epochs = 10
batch_size =256
opt = [SGD,RMSprop,Adagrad,Adam]

# %%
results = {}
"""
建立你的訓練與實驗迴圈並蒐集資料
"""
from keras.optimizers import Adam
results = {}
for optimizers in opt:
    model = build_mlp(x_train.shape[1], y_train.shape[1])
    model.summary()
    model.compile(loss="categorical_crossentropy", optimizer=optimizers(lr=LR), metrics=["accuracy"])
    model.fit(x_train, y_train, 
              epochs=epochs, 
              batch_size=batch_size, 
              validation_split=0.2, 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    
    results[optimizers] = {'train-loss': train_loss,'valid-loss': valid_loss, 'train-acc': train_acc, 'valid-acc': valid_acc}
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 256)               786688
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 81us/step - loss: 2.2856 - accuracy: 0.1401 - val_loss: 2.2511 - val_accuracy: 0.1787
# Epoch 2/10
# 40000/40000 [==============================] - 3s 78us/step - loss: 2.2284 - accuracy: 0.1932 - val_loss: 2.2092 - val_accuracy: 0.1984
# Epoch 3/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.1891 - accuracy: 0.2151 - val_loss: 2.1736 - val_accuracy: 0.2169
# Epoch 4/10
# 40000/40000 [==============================] - 3s 79us/step - loss: 2.1554 - accuracy: 0.2341 - val_loss: 2.1437 - val_accuracy: 0.2334
# Epoch 5/10
# 40000/40000 [==============================] - 3s 78us/step - loss: 2.1262 - accuracy: 0.2453 - val_loss: 2.1166 - val_accuracy: 0.2503
# Epoch 6/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.0999 - accuracy: 0.2580 - val_loss: 2.0930 - val_accuracy: 0.2559
# Epoch 7/10
# 40000/40000 [==============================] - 3s 73us/step - loss: 2.0764 - accuracy: 0.2692 - val_loss: 2.0717 - val_accuracy: 0.2718
# Epoch 8/10
# 40000/40000 [==============================] - 3s 72us/step - loss: 2.0546 - accuracy: 0.2792 - val_loss: 2.0510 - val_accuracy: 0.2818
# Epoch 9/10
# 40000/40000 [==============================] - 3s 76us/step - loss: 2.0341 - accuracy: 0.2885 - val_loss: 2.0332 - val_accuracy: 0.2903
# Epoch 10/10
# 40000/40000 [==============================] - 3s 73us/step - loss: 2.0151 - accuracy: 0.2961 - val_loss: 2.0158 - val_accuracy: 0.2928
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 256)               786688
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 87us/step - loss: 2.2846 - accuracy: 0.2017 - val_loss: 2.1699 - val_accuracy: 0.2029
# Epoch 2/10
# 40000/40000 [==============================] - 3s 85us/step - loss: 1.9304 - accuracy: 0.3040 - val_loss: 1.9023 - val_accuracy: 0.3225
# Epoch 3/10
# 40000/40000 [==============================] - 3s 87us/step - loss: 1.8319 - accuracy: 0.3399 - val_loss: 1.8214 - val_accuracy: 0.3469
# Epoch 4/10
# 40000/40000 [==============================] - 3s 86us/step - loss: 1.7611 - accuracy: 0.3688 - val_loss: 1.8671 - val_accuracy: 0.3327
# Epoch 5/10
# 40000/40000 [==============================] - 3s 85us/step - loss: 1.7060 - accuracy: 0.3869 - val_loss: 1.8972 - val_accuracy: 0.3344
# Epoch 6/10
# 40000/40000 [==============================] - 3s 85us/step - loss: 1.6696 - accuracy: 0.4043 - val_loss: 1.6998 - val_accuracy: 0.3851
# Epoch 7/10
# 40000/40000 [==============================] - 3s 85us/step - loss: 1.6241 - accuracy: 0.4192 - val_loss: 1.7267 - val_accuracy: 0.3826
# Epoch 8/10
# 40000/40000 [==============================] - 3s 86us/step - loss: 1.5976 - accuracy: 0.4281 - val_loss: 1.7106 - val_accuracy: 0.3836
# Epoch 9/10
# 40000/40000 [==============================] - 3s 85us/step - loss: 1.5685 - accuracy: 0.4408 - val_loss: 1.9293 - val_accuracy: 0.3433
# Epoch 10/10
# 40000/40000 [==============================] - 3s 87us/step - loss: 1.5501 - accuracy: 0.4451 - val_loss: 1.6722 - val_accuracy: 0.4085
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 256)               786688
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 84us/step - loss: 2.0384 - accuracy: 0.2653 - val_loss: 1.9305 - val_accuracy: 0.3025
# Epoch 2/10
# 40000/40000 [==============================] - 3s 80us/step - loss: 1.8640 - accuracy: 0.3399 - val_loss: 1.8689 - val_accuracy: 0.3402
# Epoch 3/10
# 40000/40000 [==============================] - 3s 83us/step - loss: 1.8058 - accuracy: 0.3621 - val_loss: 1.8059 - val_accuracy: 0.3574
# Epoch 4/10
# 40000/40000 [==============================] - 3s 84us/step - loss: 1.7644 - accuracy: 0.3770 - val_loss: 1.7702 - val_accuracy: 0.3736
# Epoch 5/10
# 40000/40000 [==============================] - 3s 84us/step - loss: 1.7314 - accuracy: 0.3889 - val_loss: 1.7550 - val_accuracy: 0.3794
# Epoch 6/10
# 40000/40000 [==============================] - 3s 83us/step - loss: 1.7043 - accuracy: 0.3997 - val_loss: 1.7479 - val_accuracy: 0.3784
# Epoch 7/10
# 40000/40000 [==============================] - 3s 83us/step - loss: 1.6814 - accuracy: 0.4078 - val_loss: 1.7250 - val_accuracy: 0.3927
# Epoch 8/10
# 40000/40000 [==============================] - 3s 81us/step - loss: 1.6627 - accuracy: 0.4150 - val_loss: 1.7112 - val_accuracy: 0.3986
# Epoch 9/10
# 40000/40000 [==============================] - 3s 84us/step - loss: 1.6475 - accuracy: 0.4205 - val_loss: 1.6761 - val_accuracy: 0.4148
# Epoch 10/10
# 40000/40000 [==============================] - 3s 81us/step - loss: 1.6319 - accuracy: 0.4272 - val_loss: 1.6893 - val_accuracy: 0.4019
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 256)               786688
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                650
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 4s 100us/step - loss: 1.9715 - accuracy: 0.2845 - val_loss: 1.8594 - val_accuracy: 0.3251
# Epoch 2/10
# 40000/40000 [==============================] - 4s 97us/step - loss: 1.7669 - accuracy: 0.3684 - val_loss: 1.7358 - val_accuracy: 0.3740
# Epoch 3/10
# 40000/40000 [==============================] - 4s 102us/step - loss: 1.6843 - accuracy: 0.3952 - val_loss: 1.7153 - val_accuracy: 0.3929
# Epoch 4/10
# 40000/40000 [==============================] - 4s 99us/step - loss: 1.6271 - accuracy: 0.4213 - val_loss: 1.7108 - val_accuracy: 0.3897
# Epoch 5/10
# 40000/40000 [==============================] - 4s 97us/step - loss: 1.5744 - accuracy: 0.4388 - val_loss: 1.5963 - val_accuracy: 0.4321
# Epoch 6/10
# 40000/40000 [==============================] - 4s 99us/step - loss: 1.5345 - accuracy: 0.4515 - val_loss: 1.5830 - val_accuracy: 0.4418
# Epoch 7/10
# 40000/40000 [==============================] - 4s 95us/step - loss: 1.5000 - accuracy: 0.4676 - val_loss: 1.5255 - val_accuracy: 0.4610
# Epoch 8/10
# 40000/40000 [==============================] - 4s 97us/step - loss: 1.4733 - accuracy: 0.4750 - val_loss: 1.5305 - val_accuracy: 0.4542
# Epoch 9/10
# 40000/40000 [==============================] - 4s 98us/step - loss: 1.4535 - accuracy: 0.4827 - val_loss: 1.5370 - val_accuracy: 0.4596
# Epoch 10/10
# 40000/40000 [==============================] - 4s 99us/step - loss: 1.4215 - accuracy: 0.4922 - val_loss: 1.5372 - val_accuracy: 0.4551

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

"""
將實驗結果繪出
"""

import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""

import matplotlib.pyplot as plt
# %matplotlib inline 
    
#NUM_COLORS = len(results.keys())
#cm = plt.get_cmap('gist_rainbow')
#color_bar = [cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)]

#plt.figure(figsize=(8,6))
for i, j in enumerate(results.keys()):
    plt.plot(range(len(results[j]['train-loss'])),results[j]['train-loss'], '-', label=j)
    plt.plot(range(len(results[j]['valid-loss'])),results[j]['valid-loss'], '--', label=j)
plt.title("Loss vs. Optimizers")
plt.legend(loc=4)
plt.show()

plt.figure(figsize=(8,6))
for i, j in enumerate(results.keys()):
    plt.plot(range(len(results[j]['train-acc'])),results[j]['train-acc'], '-', label=j)
    plt.plot(range(len(results[j]['valid-acc'])),results[j]['valid-acc'], '--', label=j)
plt.title("Accuracy vs. Optimizers")
plt.legend(loc=4)
plt.show()
